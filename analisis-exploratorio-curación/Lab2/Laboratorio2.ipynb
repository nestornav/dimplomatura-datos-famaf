# %% [markdown]
# # Laboratorio 2

# %% [markdown]
# Se trabajará con el dataset de permisos de edificación de San Francisco:
# https://www.kaggle.com/aparnashastry/building-permit-applications-data/data

# %%
import pandas as pd
import numpy as np
np.random.seed(32423)

# %% [markdown]
# ## Importacion de datos

# %%
dateparse = lambda c: pd.to_datetime(c, format='%m/%d/%Y', errors='coerce')
col_dates = ['Permit Creation Date', 'Current Status Date', 'Filed Date', 'Issued Date', 'Completed Date','First Construction Document Date', 'Permit Expiration Date']
data = pd.read_csv("Building_Permits.csv", low_memory=False, parse_dates=col_dates, date_parser=dateparse, \
                   index_col=['Record ID'])

# %% [markdown]
# Vemos si los tipos de datos de las columnas fueron inferidos correctamente según la información suministrada en
# https://www.kaggle.com/aparnashastry/building-permit-applications-data/data

# %%
data.dtypes
# Out:
# Permit Number                                     object
# Permit Type                                        int64
# Permit Type Definition                            object
# Permit Creation Date                      datetime64[ns]
# Block                                             object
# Lot                                               object
# Street Number                                      int64
# Street Number Suffix                              object
# Street Name                                       object
# Street Suffix                                     object
# Unit                                             float64
# Unit Suffix                                       object
# Description                                       object
# Current Status                                    object
# Current Status Date                       datetime64[ns]
# Filed Date                                datetime64[ns]
# Issued Date                               datetime64[ns]
# Completed Date                            datetime64[ns]
# First Construction Document Date          datetime64[ns]
# Structural Notification                           object
# Number of Existing Stories                       float64
# Number of Proposed Stories                       float64
# Voluntary Soft-Story Retrofit                     object
# Fire Only Permit                                  object
# Permit Expiration Date                    datetime64[ns]
# Estimated Cost                                   float64
# Revised Cost                                     float64
# Existing Use                                      object
# Existing Units                                   float64
# Proposed Use                                      object
# Proposed Units                                   float64
# Plansets                                         float64
# TIDF Compliance                                   object
# Existing Construction Type                       float64
# Existing Construction Type Description            object
# Proposed Construction Type                       float64
# Proposed Construction Type Description            object
# Site Permit                                       object
# Supervisor District                              float64
# Neighborhoods - Analysis Boundaries               object
# Zipcode                                          float64
# Location                                          object
# dtype: object

# %% [markdown]
# ### Fechas

# %% [markdown]
# Vemos cómo se parsearon las fechas nulas:

# %%
data['Completed Date'][:5]
# Out:
# Record ID
# 1380611233945          NaT
# 1420164406718          NaT
# 1424856504716          NaT
# 1443574295566   2017-07-24
# 144548169992           NaT
# Name: Completed Date, dtype: datetime64[ns]

# %%
data.describe(include='all')
# Out:
#        Permit Number    Permit Type  Permit Type Definition  \
# count         198900  198900.000000                  198900
# unique        181495            NaN                       8
# top     201602179765            NaN  otc alterations permit
# freq             101            NaN                  178844
# first            NaN            NaN                     NaN
# last             NaN            NaN                     NaN
# mean             NaN       7.522323                     NaN
# std              NaN       1.457451                     NaN
# min              NaN       1.000000                     NaN
# 25%              NaN       8.000000                     NaN
# 50%              NaN       8.000000                     NaN
# 75%              NaN       8.000000                     NaN
# max              NaN       8.000000                     NaN
#
#        Permit Creation Date   Block     Lot  Street Number  \
# count                198900  198900  198900  198900.000000
# unique                 1291    4893    1050            NaN
# top     2017-09-15 00:00:00    3708       1            NaN
# freq                    413    1195   10114            NaN
# first   2012-03-28 00:00:00     NaN     NaN            NaN
# last    2018-02-23 00:00:00     NaN     NaN            NaN
# mean                    NaN     NaN     NaN    1121.728944
# std                     NaN     NaN     NaN    1135.768948
# min                     NaN     NaN     NaN       0.000000
# 25%                     NaN     NaN     NaN     235.000000
# 50%                     NaN     NaN     NaN     710.000000
# 75%                     NaN     NaN     NaN    1700.000000
# max                     NaN     NaN     NaN    8400.000000
#
#        Street Number Suffix Street Name Street Suffix  \
# count                  2216      198900        196132
# unique                   18        1704            21
# top                       A      Market            St
# freq                   1501        5443        138358
# first                   NaN         NaN           NaN
# last                    NaN         NaN           NaN
# mean                    NaN         NaN           NaN
# std                     NaN         NaN           NaN
# min                     NaN         NaN           NaN
# 25%                     NaN         NaN           NaN
# 50%                     NaN         NaN           NaN
# 75%                     NaN         NaN           NaN
# max                     NaN         NaN           NaN
#
#                          ...                     TIDF Compliance  \
# count                    ...                                   2
# unique                   ...                                   2
# top                      ...                                   Y
# freq                     ...                                   1
# first                    ...                                 NaN
# last                     ...                                 NaN
# mean                     ...                                 NaN
# std                      ...                                 NaN
# min                      ...                                 NaN
# 25%                      ...                                 NaN
# 50%                      ...                                 NaN
# 75%                      ...                                 NaN
# max                      ...                                 NaN
#
#        Existing Construction Type Existing Construction Type Description  \
# count               155534.000000                                 155534
# unique                        NaN                                      5
# top                           NaN                         wood frame (5)
# freq                          NaN                                 113350
# first                         NaN                                    NaN
# last                          NaN                                    NaN
# mean                     4.072878                                    NaN
# std                      1.585756                                    NaN
# min                      1.000000                                    NaN
# 25%                      3.000000                                    NaN
# 50%                      5.000000                                    NaN
# 75%                      5.000000                                    NaN
# max                      5.000000                                    NaN
#
#        Proposed Construction Type Proposed Construction Type Description  \
# count               155738.000000                                 155738
# unique                        NaN                                      5
# top                           NaN                         wood frame (5)
# freq                          NaN                                 114382
# first                         NaN                                    NaN
# last                          NaN                                    NaN
# mean                     4.089529                                    NaN
# std                      1.578766                                    NaN
# min                      1.000000                                    NaN
# 25%                      3.000000                                    NaN
# 50%                      5.000000                                    NaN
# 75%                      5.000000                                    NaN
# max                      5.000000                                    NaN
#
#        Site Permit Supervisor District Neighborhoods - Analysis Boundaries  \
# count         5359       197183.000000                              197175
# unique           1                 NaN                                  41
# top              Y                 NaN      Financial District/South Beach
# freq          5359                 NaN                               21816
# first          NaN                 NaN                                 NaN
# last           NaN                 NaN                                 NaN
# mean           NaN            5.538403                                 NaN
# std            NaN            2.887041                                 NaN
# min            NaN            1.000000                                 NaN
# 25%            NaN            3.000000                                 NaN
# 50%            NaN            6.000000                                 NaN
# 75%            NaN            8.000000                                 NaN
# max            NaN           11.000000                                 NaN
#
#               Zipcode                                 Location
# count   197184.000000                                   197200
# unique            NaN                                    57604
# top               NaN  (37.79226164705184, -122.4034859571375)
# freq              NaN                                      554
# first             NaN                                      NaN
# last              NaN                                      NaN
# mean     94115.500558                                      NaN
# std          9.270131                                      NaN
# min      94102.000000                                      NaN
# 25%      94109.000000                                      NaN
# 50%      94114.000000                                      NaN
# 75%      94122.000000                                      NaN
# max      94158.000000                                      NaN
#
# [13 rows x 42 columns]

# %% [markdown]
# Ahora deberíamos poder calcular el rango de fechas para cada columna de tipo date

# %%
for date_type_col in col_dates:
    print(data[date_type_col].max() - data[date_type_col].min())
# Out:
# 2158 days 00:00:00
# 2250 days 00:00:00
# 1878 days 00:00:00
# 1878 days 00:00:00
# 1876 days 00:00:00
# 1878 days 00:00:00
# 3873 days 00:00:00

# %% [markdown]
# ## Asegurar de tener ids/claves únicas

# %% [markdown]
# Vemos si hay IDs duplicados

# %%
data[data.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# Ver si hay filas duplicadas y descartarlas

# %%
data[data.duplicated()]
# Out:
#               Permit Number  Permit Type            Permit Type Definition  \
# Record ID
# 1294939199934  201302019267            8            otc alterations permit
# 1300835395703  201303283290            8            otc alterations permit
# 1301529164635  201304124392            8            otc alterations permit
# 1308830100339  201306210141            2       new construction wood frame
# 1316521206878  201309056009            8            otc alterations permit
# 1317158490355  201309116496            8            otc alterations permit
# 1319970206124  201310078627            8            otc alterations permit
# 1319981387943  201309045902            8            otc alterations permit
# 1320387100653  201310108954            8            otc alterations permit
# 1320438118710  201310108990            8            otc alterations permit
# 1321690416908  201310229954            8            otc alterations permit
# 1321961102273  201310240168            8            otc alterations permit
# 132438569891        M444587            8            otc alterations permit
# 1324681170997       M445387            8            otc alterations permit
# 1325247493716  201311252729            8            otc alterations permit
# 132623099137   201312063490            8            otc alterations permit
# 132774263349   201312204701            8            otc alterations permit
# 1334249465250       M467927            8            otc alterations permit
# 1335255436500  201403120593            8            otc alterations permit
# 1337412393485  201402057839            8            otc alterations permit
# 1342196420228  201405165994            8            otc alterations permit
# 1342252496263       M489027            8            otc alterations permit
# 134303490330   201404153296            8            otc alterations permit
# 134870373331        M503928            8            otc alterations permit
# 1349370392081  201407181601            8            otc alterations permit
# 1350144289258  201407252216            8            otc alterations permit
# 1356614144941       M520487            8            otc alterations permit
# 135887277085        M527287            8            otc alterations permit
# 1362652404491       M537887            8            otc alterations permit
# 1364264394477  201412042999            8            otc alterations permit
# ...                     ...          ...                               ...
# 1406565249051       M646687            8            otc alterations permit
# 1407193164635  201512215598            3  additions alterations or repairs
# 1411187159237  201602028646            8            otc alterations permit
# 141370258893   201512175353            8            otc alterations permit
# 1423046419304  201605127286            8            otc alterations permit
# 142405696527   201605208035            8            otc alterations permit
# 1427347504407       M699308            8            otc alterations permit
# 1433589450534  201608124949            3  additions alterations or repairs
# 1448640491307  201612275918            1                  new construction
# 1454408508529  201702270179            8            otc alterations permit
# 1455163266268  201702099112            8            otc alterations permit
# 145516457812   201702099112            8            otc alterations permit
# 1460314165260       M779929            8            otc alterations permit
# 1460729231465  201702099056            3  additions alterations or repairs
# 1461223125343  201612144960            3  additions alterations or repairs
# 1463991501743  201612215594            3  additions alterations or repairs
# 1466273273818  201706088863            3  additions alterations or repairs
# 147236396498        M814467            8            otc alterations permit
# 1472719133304  201708013471            8            otc alterations permit
# 1482034460857  201708094308            3  additions alterations or repairs
# 1462555164581  201705106189            8            otc alterations permit
# 1473298165379  201706209859            3  additions alterations or repairs
# 1476566240893  201708296228            3  additions alterations or repairs
# 1478281175439  201709117498            8            otc alterations permit
# 147956058966   201709158445            8            otc alterations permit
# 1483262510015  201704285242            3  additions alterations or repairs
# 1485307166219  201710030226            3  additions alterations or repairs
# 1485309166219  201710030226            3  additions alterations or repairs
# 1497003510271  201802131156            8            otc alterations permit
# 1497587159387  201802161603            8            otc alterations permit
#
#               Permit Creation Date Block   Lot  Street Number  \
# Record ID
# 1294939199934           2013-02-01  6280    43            806
# 1300835395703           2013-03-28  3987    24            135
# 1301529164635           2013-04-12  3717     5            160
# 1308830100339           2013-06-21  1453    13            363
# 1316521206878           2013-09-05  6541    15           4757
# 1317158490355           2013-09-11   950    60           2768
# 1319970206124           2013-10-07  6522    15           2870
# 1319981387943           2013-09-04  1065  026A           3244
# 1320387100653           2013-10-10  1460  001P            479
# 1320438118710           2013-10-10  1883    48           1510
# 1321690416908           2013-10-22   663    53           1963
# 1321961102273           2013-10-24  1511  042A            510
# 132438569891            2013-11-15   335    26            600
# 1324681170997           2013-11-19  4142    30            949
# 1325247493716           2013-11-25  3779   231            780
# 132623099137            2013-12-06  1423    50            918
# 132774263349            2013-12-20   232    16              3
# 1334249465250           2014-03-04  3721   122            531
# 1335255436500           2014-03-12  4991   277            837
# 1337412393485           2014-02-05  1456    52           6050
# 1342196420228           2014-05-16   565    18           2660
# 1342252496263           2014-05-16  1434    35            330
# 134303490330            2014-04-15  1139     5            169
# 134870373331            2014-07-11   533     1           2961
# 1349370392081           2014-07-18  5311    36           4705
# 1350144289258           2014-07-25   204    21              1
# 1356614144941           2014-09-24  2819    20            256
# 135887277085            2014-10-14   634     6           2526
# 1362652404491           2014-11-17  1218     7            301
# 1364264394477           2014-12-04  3708    96             55
# ...                            ...   ...   ...            ...
# 1406565249051           2015-12-15  3654     4           1072
# 1407193164635           2015-12-21  3717     5            160
# 1411187159237           2016-02-02  3571  004A            274
# 141370258893            2015-12-17   101     4           1731
# 1423046419304           2016-05-12  3725    20            964
# 142405696527            2016-05-20  1352    35             95
# 1427347504407           2016-06-20   716    15            888
# 1433589450534           2016-08-12  8702   525            260
# 1448640491307           2016-12-27  3736   107             58
# 1454408508529           2017-02-27  3983     1           1421
# 1455163266268           2017-02-09    76    15            676
# 145516457812            2017-02-09    76    15            666
# 1460314165260           2017-04-21  3730    28           1192
# 1460729231465           2017-02-09   103    39           1539
# 1461223125343           2016-12-14  2088  001F           1939
# 1463991501743           2016-12-21  1367    34            160
# 1466273273818           2017-06-08  1155    20            926
# 147236396498            2017-07-28  1352    11             55
# 1472719133304           2017-08-01  2376     4           2315
# 1482034460857           2017-08-09  4224    36           1033
# 1462555164581           2017-05-10  3709    19             50
# 1473298165379           2017-06-20  3731    71           1069
# 1476566240893           2017-08-29  1242     1            969
# 1478281175439           2017-09-11  4829     6           1550
# 147956058966            2017-09-15   103    35            525
# 1483262510015           2017-04-28  3727    54            646
# 1485307166219           2017-10-03  3753    81            345
# 1485309166219           2017-10-03  3753    81            345
# 1497003510271           2018-02-13  5315    51           2027
# 1497587159387           2018-02-16  3575    91           2101
#
#               Street Number Suffix           Street Name Street Suffix  \
# Record ID
# 1294939199934                  NaN                Russia            Av
# 1300835395703                  NaN           Mississippi            St
# 1301529164635                  NaN                 Spear            St
# 1308830100339                  NaN                  21st            Av
# 1316521206878                  NaN                  25th            St
# 1317158490355                  NaN                 Green            St
# 1319970206124                  NaN              Harrison            St
# 1319981387943                  NaN                 Geary            Bl
# 1320387100653                  NaN                  28th            Av
# 1320438118710                  NaN                  38th            Av
# 1321690416908                  NaN                  Pine            St
# 1321961102273                  NaN                  34th            Av
# 132438569891                   NaN                Larkin            St
# 1324681170997                  NaN             Hampshire            St
# 1325247493716                  NaN               Brannan            St
# 132623099137                   NaN               Clement            St
# 132774263349                   NaN    Embarcadero Center           NaN
# 1334249465250                  NaN  Situs To Be Assigned            St
# 1335255436500                  NaN             Jamestown            Av
# 1337412393485                  NaN                 Geary            Bl
# 1342196420228                  NaN               Webster            St
# 1342252496263                    A                  03rd            Av
# 134303490330                   NaN               Stanyan            St
# 134870373331                   NaN               Webster            St
# 1349370392081                  NaN                  03rd            St
# 1350144289258                  NaN              Maritime            Pz
# 1356614144941                  NaN          Laguna Honda            Bl
# 135887277085                   NaN            California            St
# 1362652404491                  NaN            Divisadero            St
# 1364264394477                  NaN                  02nd            St
# ...                            ...                   ...           ...
# 1406565249051                  NaN               Sanchez            St
# 1407193164635                  NaN                 Spear            St
# 1411187159237                  NaN              Shotwell            St
# 141370258893                   NaN                Powell            St
# 1423046419304                  NaN                Howard            St
# 142405696527                   NaN                  06th            Av
# 1427347504407                  NaN              Ofarrell            St
# 1433589450534                  NaN                  King            St
# 1448640491307                  NaN                Tehama            St
# 1454408508529                  NaN                  17th            St
# 1455163266268                  NaN             Greenwich            St
# 145516457812                   NaN             Greenwich            St
# 1460314165260                  NaN                Folsom            St
# 1460729231465                  NaN                 Grant            Av
# 1461223125343                  NaN                  46th            Av
# 1463991501743                  NaN                  08th            Av
# 1466273273818                  NaN            Divisadero            St
# 147236396498                   NaN                  06th            Av
# 1472719133304                  NaN                  47th            Av
# 1482034460857                  NaN                 Texas            St
# 1462555164581                  NaN               Fremont            St
# 1473298165379                  NaN                Howard            St
# 1476566240893                  NaN           Buena Vista            Tr
# 1478281175439                  NaN               Wallace            Av
# 147956058966                   NaN               Filbert            St
# 1483262510015                    B                Natoma            St
# 1485307166219                  NaN                  06th            St
# 1485309166219                  NaN                  06th            St
# 1497003510271                  NaN               Newcomb            Av
# 1497587159387                  NaN               Mission            St
#
#                                  ...                      TIDF Compliance  \
# Record ID                        ...
# 1294939199934                    ...                                  NaN
# 1300835395703                    ...                                  NaN
# 1301529164635                    ...                                  NaN
# 1308830100339                    ...                                  NaN
# 1316521206878                    ...                                  NaN
# 1317158490355                    ...                                  NaN
# 1319970206124                    ...                                  NaN
# 1319981387943                    ...                                  NaN
# 1320387100653                    ...                                  NaN
# 1320438118710                    ...                                  NaN
# 1321690416908                    ...                                  NaN
# 1321961102273                    ...                                  NaN
# 132438569891                     ...                                  NaN
# 1324681170997                    ...                                  NaN
# 1325247493716                    ...                                  NaN
# 132623099137                     ...                                  NaN
# 132774263349                     ...                                  NaN
# 1334249465250                    ...                                  NaN
# 1335255436500                    ...                                  NaN
# 1337412393485                    ...                                  NaN
# 1342196420228                    ...                                  NaN
# 1342252496263                    ...                                  NaN
# 134303490330                     ...                                  NaN
# 134870373331                     ...                                  NaN
# 1349370392081                    ...                                  NaN
# 1350144289258                    ...                                  NaN
# 1356614144941                    ...                                  NaN
# 135887277085                     ...                                  NaN
# 1362652404491                    ...                                  NaN
# 1364264394477                    ...                                  NaN
# ...                              ...                                  ...
# 1406565249051                    ...                                  NaN
# 1407193164635                    ...                                  NaN
# 1411187159237                    ...                                  NaN
# 141370258893                     ...                                  NaN
# 1423046419304                    ...                                  NaN
# 142405696527                     ...                                  NaN
# 1427347504407                    ...                                  NaN
# 1433589450534                    ...                                  NaN
# 1448640491307                    ...                                  NaN
# 1454408508529                    ...                                  NaN
# 1455163266268                    ...                                  NaN
# 145516457812                     ...                                  NaN
# 1460314165260                    ...                                  NaN
# 1460729231465                    ...                                  NaN
# 1461223125343                    ...                                  NaN
# 1463991501743                    ...                                  NaN
# 1466273273818                    ...                                  NaN
# 147236396498                     ...                                  NaN
# 1472719133304                    ...                                  NaN
# 1482034460857                    ...                                  NaN
# 1462555164581                    ...                                  NaN
# 1473298165379                    ...                                  NaN
# 1476566240893                    ...                                  NaN
# 1478281175439                    ...                                  NaN
# 147956058966                     ...                                  NaN
# 1483262510015                    ...                                  NaN
# 1485307166219                    ...                                  NaN
# 1485309166219                    ...                                  NaN
# 1497003510271                    ...                                  NaN
# 1497587159387                    ...                                  NaN
#
#               Existing Construction Type  \
# Record ID
# 1294939199934                        5.0
# 1300835395703                        5.0
# 1301529164635                        1.0
# 1308830100339                        NaN
# 1316521206878                        5.0
# 1317158490355                        5.0
# 1319970206124                        5.0
# 1319981387943                        5.0
# 1320387100653                        5.0
# 1320438118710                        5.0
# 1321690416908                        5.0
# 1321961102273                        5.0
# 132438569891                         NaN
# 1324681170997                        NaN
# 1325247493716                        5.0
# 132623099137                         5.0
# 132774263349                         1.0
# 1334249465250                        NaN
# 1335255436500                        5.0
# 1337412393485                        5.0
# 1342196420228                        5.0
# 1342252496263                        NaN
# 134303490330                         5.0
# 134870373331                         NaN
# 1349370392081                        5.0
# 1350144289258                        1.0
# 1356614144941                        NaN
# 135887277085                         NaN
# 1362652404491                        NaN
# 1364264394477                        1.0
# ...                                  ...
# 1406565249051                        NaN
# 1407193164635                        1.0
# 1411187159237                        5.0
# 141370258893                         5.0
# 1423046419304                        3.0
# 142405696527                         5.0
# 1427347504407                        NaN
# 1433589450534                        1.0
# 1448640491307                        NaN
# 1454408508529                        5.0
# 1455163266268                        5.0
# 145516457812                         5.0
# 1460314165260                        NaN
# 1460729231465                        5.0
# 1461223125343                        5.0
# 1463991501743                        5.0
# 1466273273818                        5.0
# 147236396498                         NaN
# 1472719133304                        5.0
# 1482034460857                        5.0
# 1462555164581                        1.0
# 1473298165379                        2.0
# 1476566240893                        5.0
# 1478281175439                        2.0
# 147956058966                         5.0
# 1483262510015                        5.0
# 1485307166219                        NaN
# 1485309166219                        NaN
# 1497003510271                        3.0
# 1497587159387                        3.0
#
#               Existing Construction Type Description  \
# Record ID
# 1294939199934                         wood frame (5)
# 1300835395703                         wood frame (5)
# 1301529164635                          constr type 1
# 1308830100339                                    NaN
# 1316521206878                         wood frame (5)
# 1317158490355                         wood frame (5)
# 1319970206124                         wood frame (5)
# 1319981387943                         wood frame (5)
# 1320387100653                         wood frame (5)
# 1320438118710                         wood frame (5)
# 1321690416908                         wood frame (5)
# 1321961102273                         wood frame (5)
# 132438569891                                     NaN
# 1324681170997                                    NaN
# 1325247493716                         wood frame (5)
# 132623099137                          wood frame (5)
# 132774263349                           constr type 1
# 1334249465250                                    NaN
# 1335255436500                         wood frame (5)
# 1337412393485                         wood frame (5)
# 1342196420228                         wood frame (5)
# 1342252496263                                    NaN
# 134303490330                          wood frame (5)
# 134870373331                                     NaN
# 1349370392081                         wood frame (5)
# 1350144289258                          constr type 1
# 1356614144941                                    NaN
# 135887277085                                     NaN
# 1362652404491                                    NaN
# 1364264394477                          constr type 1
# ...                                              ...
# 1406565249051                                    NaN
# 1407193164635                          constr type 1
# 1411187159237                         wood frame (5)
# 141370258893                          wood frame (5)
# 1423046419304                          constr type 3
# 142405696527                          wood frame (5)
# 1427347504407                                    NaN
# 1433589450534                          constr type 1
# 1448640491307                                    NaN
# 1454408508529                         wood frame (5)
# 1455163266268                         wood frame (5)
# 145516457812                          wood frame (5)
# 1460314165260                                    NaN
# 1460729231465                         wood frame (5)
# 1461223125343                         wood frame (5)
# 1463991501743                         wood frame (5)
# 1466273273818                         wood frame (5)
# 147236396498                                     NaN
# 1472719133304                         wood frame (5)
# 1482034460857                         wood frame (5)
# 1462555164581                          constr type 1
# 1473298165379                          constr type 2
# 1476566240893                         wood frame (5)
# 1478281175439                          constr type 2
# 147956058966                          wood frame (5)
# 1483262510015                         wood frame (5)
# 1485307166219                                    NaN
# 1485309166219                                    NaN
# 1497003510271                          constr type 3
# 1497587159387                          constr type 3
#
#               Proposed Construction Type  \
# Record ID
# 1294939199934                        5.0
# 1300835395703                        5.0
# 1301529164635                        1.0
# 1308830100339                        5.0
# 1316521206878                        5.0
# 1317158490355                        5.0
# 1319970206124                        5.0
# 1319981387943                        5.0
# 1320387100653                        5.0
# 1320438118710                        5.0
# 1321690416908                        5.0
# 1321961102273                        5.0
# 132438569891                         NaN
# 1324681170997                        NaN
# 1325247493716                        5.0
# 132623099137                         5.0
# 132774263349                         1.0
# 1334249465250                        NaN
# 1335255436500                        5.0
# 1337412393485                        5.0
# 1342196420228                        5.0
# 1342252496263                        NaN
# 134303490330                         5.0
# 134870373331                         NaN
# 1349370392081                        5.0
# 1350144289258                        1.0
# 1356614144941                        NaN
# 135887277085                         NaN
# 1362652404491                        NaN
# 1364264394477                        1.0
# ...                                  ...
# 1406565249051                        NaN
# 1407193164635                        1.0
# 1411187159237                        5.0
# 141370258893                         5.0
# 1423046419304                        3.0
# 142405696527                         5.0
# 1427347504407                        NaN
# 1433589450534                        1.0
# 1448640491307                        1.0
# 1454408508529                        5.0
# 1455163266268                        5.0
# 145516457812                         5.0
# 1460314165260                        NaN
# 1460729231465                        5.0
# 1461223125343                        5.0
# 1463991501743                        5.0
# 1466273273818                        5.0
# 147236396498                         NaN
# 1472719133304                        5.0
# 1482034460857                        5.0
# 1462555164581                        1.0
# 1473298165379                        2.0
# 1476566240893                        5.0
# 1478281175439                        2.0
# 147956058966                         5.0
# 1483262510015                        5.0
# 1485307166219                        NaN
# 1485309166219                        NaN
# 1497003510271                        3.0
# 1497587159387                        3.0
#
#               Proposed Construction Type Description Site Permit  \
# Record ID
# 1294939199934                         wood frame (5)         NaN
# 1300835395703                         wood frame (5)         NaN
# 1301529164635                          constr type 1         NaN
# 1308830100339                         wood frame (5)           Y
# 1316521206878                         wood frame (5)         NaN
# 1317158490355                         wood frame (5)         NaN
# 1319970206124                         wood frame (5)         NaN
# 1319981387943                         wood frame (5)         NaN
# 1320387100653                         wood frame (5)         NaN
# 1320438118710                         wood frame (5)         NaN
# 1321690416908                         wood frame (5)         NaN
# 1321961102273                         wood frame (5)         NaN
# 132438569891                                     NaN         NaN
# 1324681170997                                    NaN         NaN
# 1325247493716                         wood frame (5)         NaN
# 132623099137                          wood frame (5)         NaN
# 132774263349                           constr type 1         NaN
# 1334249465250                                    NaN         NaN
# 1335255436500                         wood frame (5)         NaN
# 1337412393485                         wood frame (5)         NaN
# 1342196420228                         wood frame (5)         NaN
# 1342252496263                                    NaN         NaN
# 134303490330                          wood frame (5)         NaN
# 134870373331                                     NaN         NaN
# 1349370392081                         wood frame (5)         NaN
# 1350144289258                          constr type 1         NaN
# 1356614144941                                    NaN         NaN
# 135887277085                                     NaN         NaN
# 1362652404491                                    NaN         NaN
# 1364264394477                          constr type 1         NaN
# ...                                              ...         ...
# 1406565249051                                    NaN         NaN
# 1407193164635                          constr type 1         NaN
# 1411187159237                         wood frame (5)         NaN
# 141370258893                          wood frame (5)         NaN
# 1423046419304                          constr type 3         NaN
# 142405696527                          wood frame (5)         NaN
# 1427347504407                                    NaN         NaN
# 1433589450534                          constr type 1         NaN
# 1448640491307                          constr type 1           Y
# 1454408508529                         wood frame (5)         NaN
# 1455163266268                         wood frame (5)         NaN
# 145516457812                          wood frame (5)         NaN
# 1460314165260                                    NaN         NaN
# 1460729231465                         wood frame (5)         NaN
# 1461223125343                         wood frame (5)         NaN
# 1463991501743                         wood frame (5)         NaN
# 1466273273818                         wood frame (5)         NaN
# 147236396498                                     NaN         NaN
# 1472719133304                         wood frame (5)         NaN
# 1482034460857                         wood frame (5)           Y
# 1462555164581                          constr type 1         NaN
# 1473298165379                          constr type 2         NaN
# 1476566240893                         wood frame (5)           Y
# 1478281175439                          constr type 2         NaN
# 147956058966                          wood frame (5)         NaN
# 1483262510015                         wood frame (5)         NaN
# 1485307166219                                    NaN         NaN
# 1485309166219                                    NaN         NaN
# 1497003510271                          constr type 3         NaN
# 1497587159387                          constr type 3         NaN
#
#               Supervisor District Neighborhoods - Analysis Boundaries  \
# Record ID
# 1294939199934                11.0                           Excelsior
# 1300835395703                10.0                        Potrero Hill
# 1301529164635                 6.0      Financial District/South Beach
# 1308830100339                 1.0                      Outer Richmond
# 1316521206878                 8.0                          Noe Valley
# 1317158490355                 2.0                              Marina
# 1319970206124                 9.0                             Mission
# 1319981387943                 2.0                    Presidio Heights
# 1320387100653                 1.0                      Outer Richmond
# 1320438118710                 4.0                     Sunset/Parkside
# 1321690416908                 5.0                     Pacific Heights
# 1321961102273                 1.0                      Outer Richmond
# 132438569891                  6.0                          Tenderloin
# 1324681170997                 9.0                        Potrero Hill
# 1325247493716                 6.0                     South of Market
# 132623099137                  1.0                      Inner Richmond
# 132774263349                  3.0      Financial District/South Beach
# 1334249465250                 6.0      Financial District/South Beach
# 1335255436500                10.0               Bayview Hunters Point
# 1337412393485                 1.0                      Outer Richmond
# 1342196420228                 2.0                     Pacific Heights
# 1342252496263                 1.0                      Inner Richmond
# 134303490330                  1.0                   Lone Mountain/USF
# 134870373331                  2.0                              Marina
# 1349370392081                10.0               Bayview Hunters Point
# 1350144289258                 3.0      Financial District/South Beach
# 1356614144941                 7.0                  West of Twin Peaks
# 135887277085                  2.0                     Pacific Heights
# 1362652404491                 5.0                      Haight Ashbury
# 1364264394477                 6.0      Financial District/South Beach
# ...                           ...                                 ...
# 1406565249051                 8.0                          Noe Valley
# 1407193164635                 6.0      Financial District/South Beach
# 1411187159237                 9.0                             Mission
# 141370258893                  3.0                           Chinatown
# 1423046419304                 6.0                     South of Market
# 142405696527                  2.0                      Inner Richmond
# 1427347504407                 6.0                          Tenderloin
# 1433589450534                 6.0                         Mission Bay
# 1448640491307                 6.0      Financial District/South Beach
# 1454408508529                10.0                        Potrero Hill
# 1455163266268                 3.0                         North Beach
# 145516457812                  3.0                         North Beach
# 1460314165260                 6.0                     South of Market
# 1460729231465                 3.0                         North Beach
# 1461223125343                 4.0                     Sunset/Parkside
# 1463991501743                 1.0                      Inner Richmond
# 1466273273818                 5.0                    Western Addition
# 147236396498                  2.0                      Inner Richmond
# 1472719133304                 4.0                     Sunset/Parkside
# 1482034460857                10.0                        Potrero Hill
# 1462555164581                 6.0      Financial District/South Beach
# 1473298165379                 6.0                     South of Market
# 1476566240893                 5.0                      Haight Ashbury
# 1478281175439                10.0               Bayview Hunters Point
# 147956058966                  3.0                         North Beach
# 1483262510015                 6.0                     South of Market
# 1485307166219                 6.0                     South of Market
# 1485309166219                 6.0                     South of Market
# 1497003510271                10.0               Bayview Hunters Point
# 1497587159387                 9.0                             Mission
#
#                Zipcode                                   Location
# Record ID
# 1294939199934  94112.0   (37.71823948380821, -122.43070649984861)
# 1300835395703  94107.0     (37.76459192915239, -122.394376794674)
# 1301529164635  94105.0    (37.79157492973848, -122.3933901193989)
# 1308830100339  94121.0   (37.78102771976823, -122.48083375518638)
# 1316521206878  94114.0   (37.74899533171904, -122.44245690967995)
# 1317158490355  94123.0    (37.79526103815182, -122.4446242886346)
# 1319970206124  94110.0   (37.75149830307405, -122.41212947058871)
# 1319981387943  94118.0    (37.78192732986077, -122.4540305963071)
# 1320387100653  94121.0    (37.7804053854789, -122.48826767221813)
# 1320438118710  94122.0   (37.75866475318028, -122.49691713414039)
# 1321690416908  94109.0   (37.78838151551075, -122.42801768024557)
# 1321961102273  94121.0   (37.77932260734297, -122.49413043713662)
# 132438569891   94109.0   (37.78366230111203, -122.41699611775327)
# 1324681170997  94110.0    (37.7569215340585, -122.40740203223106)
# 1325247493716  94103.0  (37.773545523400244, -122.40304002124687)
# 132623099137   94118.0  (37.782941492971666, -122.46919904441467)
# 132774263349   94111.0    (37.79494825891712, -122.3972981233132)
# 1334249465250  94105.0  (37.788860440679855, -122.39810887204067)
# 1335255436500  94124.0  (37.717266595468416, -122.39226535373217)
# 1337412393485  94121.0   (37.78040846138334, -122.48458208823232)
# 1342196420228  94123.0   (37.79533855743224, -122.43317037222144)
# 1342252496263  94118.0  (37.782555255619556, -122.46083872527717)
# 134303490330   94118.0   (37.77836165248538, -122.45565189205091)
# 134870373331   94123.0   (37.798066441059824, -122.4342970790457)
# 1349370392081  94124.0   (37.73501302711392, -122.39013276908845)
# 1350144289258  94111.0  (37.795606967751475, -122.39922677527957)
# 1356614144941  94116.0   (37.74951833332695, -122.46075126349487)
# 135887277085   94115.0   (37.78890967588301, -122.43605440057925)
# 1362652404491  94117.0   (37.77230349941862, -122.43752807799265)
# 1364264394477  94105.0   (37.78888662946692, -122.40031877127271)
# ...                ...                                        ...
# 1406565249051  94114.0  (37.751974586758855, -122.43001319788962)
# 1407193164635  94105.0    (37.79157492973848, -122.3933901193989)
# 1411187159237  94110.0    (37.76410661744883, -122.4164869356017)
# 141370258893   94133.0  (37.800680942205716, -122.41128167116764)
# 1423046419304  94103.0   (37.78053912662844, -122.40654257919573)
# 142405696527   94118.0   (37.78683930574926, -122.46498001964483)
# 1427347504407  94109.0   (37.78529619229401, -122.41901375955334)
# 1433589450534  94107.0  (37.777642220223974, -122.39341813656613)
# 1448640491307  94105.0   (37.78730631115266, -122.39696707744778)
# 1454408508529  94107.0   (37.76489198606386, -122.39802971025247)
# 1455163266268  94133.0   (37.80238668129953, -122.41072699614303)
# 145516457812   94133.0   (37.80238668129953, -122.41072699614303)
# 1460314165260  94103.0   (37.77529618156755, -122.41007420256702)
# 1460729231465  94133.0  (37.801207998331606, -122.40794546408708)
# 1461223125343  94116.0   (37.75032399845832, -122.50555251211033)
# 1463991501743  94118.0   (37.78548819218033, -122.46641860386909)
# 1466273273818  94115.0    (37.77827047373019, -122.4380993145805)
# 147236396498   94118.0  (37.787556686637416, -122.46508392419878)
# 1472719133304  94116.0   (37.74322935557895, -122.50612699610814)
# 1482034460857  94107.0    (37.7532914793301, -122.39435689469667)
# 1462555164581  94105.0   (37.79057144260876, -122.39756503160109)
# 1473298165379  94103.0  (37.778307551012595, -122.40852080914514)
# 1476566240893  94117.0   (37.770224352816335, -122.4434436223119)
# 1478281175439  94124.0  (37.727168081201874, -122.39002914912902)
# 147956058966   94133.0  (37.801310363829174, -122.40820685838955)
# 1483262510015  94103.0   (37.77766987110252, -122.41115329910336)
# 1485307166219  94107.0   (37.77816488908929, -122.40467740025565)
# 1485309166219  94107.0   (37.77816488908929, -122.40467740025565)
# 1497003510271  94124.0   (37.73942407665534, -122.39791027216111)
# 1497587159387  94110.0   (37.76315349284454, -122.41898170493367)
#
# [69 rows x 42 columns]

# %%
data = data.drop_duplicates()
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# ## Caracteres especiales en nombres de las columnas

# %%
import chardet
# look at the first ten thousand bytes to guess the character encoding
with open("Building_Permits.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)
# Out:
# {'confidence': 1.0, 'encoding': 'ascii', 'language': ''}

# %% [markdown]
# El encoding resulta ser ASCII. Chequeamos que no hayan caracteres fuera de la A-Z y 0-9:

# %%
cols_special_chars = data.columns[data.columns != data.columns.str.extract(r'^(\w+)$')] 
cols_special_chars
# Out:
# /Users/andres/miniconda3/envs/dsaml/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Street Number', 'Street Number Suffix',
#        'Street Name', 'Street Suffix', 'Unit Suffix', 'Current Status',
#        'Current Status Date', 'Filed Date', 'Issued Date', 'Completed Date',
#        'First Construction Document Date', 'Structural Notification',
#        'Number of Existing Stories', 'Number of Proposed Stories',
#        'Voluntary Soft-Story Retrofit', 'Fire Only Permit',
#        'Permit Expiration Date', 'Estimated Cost', 'Revised Cost',
#        'Existing Use', 'Existing Units', 'Proposed Use', 'Proposed Units',
#        'TIDF Compliance', 'Existing Construction Type',
#        'Existing Construction Type Description', 'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ', '_')
data.columns = data.columns.str.replace('[^\w]+', '')
data.columns = data.columns.str.lower()
data.columns
# Out:
# Index(['permit_number', 'permit_type', 'permit_type_definition',
#        'permit_creation_date', 'block', 'lot', 'street_number',
#        'street_number_suffix', 'street_name', 'street_suffix', 'unit',
#        'unit_suffix', 'description', 'current_status', 'current_status_date',
#        'filed_date', 'issued_date', 'completed_date',
#        'first_construction_document_date', 'structural_notification',
#        'number_of_existing_stories', 'number_of_proposed_stories',
#        'voluntary_softstory_retrofit', 'fire_only_permit',
#        'permit_expiration_date', 'estimated_cost', 'revised_cost',
#        'existing_use', 'existing_units', 'proposed_use', 'proposed_units',
#        'plansets', 'tidf_compliance', 'existing_construction_type',
#        'existing_construction_type_description', 'proposed_construction_type',
#        'proposed_construction_type_description', 'site_permit',
#        'supervisor_district', 'neighborhoods__analysis_boundaries', 'zipcode',
#        'location'],
#       dtype='object')

# %% [markdown]
# ## Valores faltantes

# %% [markdown]
# Veamos el % de filas las cuales tienen al menos un dato nulo:

# %%
len(data.dropna(axis=1)) / len(data) * 100
# Out:
# 100.0

# %% [markdown]
# Claramente, tirar las filas con datos nulos no es una opción, ya que todas tienen al menos una columna nula.

# %% [markdown]
# ### Rellenar con algún valor los campos con datos faltantes

# %% [markdown]
# Analizamos el % de datos faltantes en cada columna

# %%
missing_values_count = data.isna().sum()
(missing_values_count[missing_values_count > 0] / len(data)).to_frame()
# Out:
#                                                0
# street_number_suffix                    0.988865
# street_suffix                           0.013916
# unit                                    0.851789
# unit_suffix                             0.990142
# description                             0.001448
# issued_date                             0.075079
# completed_date                          0.511339
# first_construction_document_date        0.075109
# structural_notification                 0.965192
# number_of_existing_stories              0.215072
# number_of_proposed_stories              0.215505
# voluntary_softstory_retrofit            0.999824
# fire_only_permit                        0.905347
# permit_expiration_date                  0.260784
# estimated_cost                          0.191364
# revised_cost                            0.030478
# existing_use                            0.206678
# existing_units                          0.259094
# proposed_use                            0.213352
# proposed_units                          0.255951
# plansets                                0.187556
# tidf_compliance                         0.999990
# existing_construction_type              0.217999
# existing_construction_type_description  0.217999
# proposed_construction_type              0.216983
# proposed_construction_type_description  0.216983
# site_permit                             0.973068
# supervisor_district                     0.008630
# neighborhoods__analysis_boundaries      0.008671
# zipcode                                 0.008625
# location                                0.008545

# %% [markdown]
# Antes de descartar los valores nulos, analicemos las columnas a las que le faltan un % elevado de datos (más del 50%).
# Nos valemos de la información adicional provista en https://www.kaggle.com/aparnashastry/building-permit-applications-data/data donde podemos encontar una breve descripción sobre cada columna.
#
# 1. street_number_suffix: es NULL el 98,86% de las filas, lo cual tiene sentido porque se trata
# de una información complementaria al número de la calle que se utiliza en casos muy puntuales (street_number por su
# parte no figura siquiera entre las columnas con algún dato faltante).
# 2. unit: está documentado como "unit of a building". No está claro si el valor es optativo; la alta cantidad de filas de este tipo sugeriría que sí.
# 3. unit_suffix: Información adicional de la columna anterior; puede ser null.
# 4. completed_data: Esta columna puede ser nula si no se terminó de edificar aún.

# %% [markdown]
# Ahora analizamos una serie de columnas en las que se indica si la edificación posee o no cierta cualidad. A primera vista, parece que se ha indicado únicamente las edificaciones que poseen esa cualidad con 'Y' y se ha dejado en blanco aquellas que no lo hacen. En tal caso, se podría rellenar esas columnas con datos faltantes con 'N' (o directamente binarizar el campo y marcar con '0' y '1'). Veamos si esto es así:

# %%
print('structural_notification\n' + str(data.structural_notification.value_counts()))
print('voluntary_softstory_retrofit\n' + str(data.voluntary_softstory_retrofit.value_counts()))
print('fire_only_permit\n' + str(data.fire_only_permit.value_counts()))
print('tidf_compliance\n' + str(data.tidf_compliance.value_counts()))
print('site_permit\n' + str(data.site_permit.value_counts()))
# Out:
# structural_notification
# Y    6921
# Name: structural_notification, dtype: int64
# voluntary_softstory_retrofit
# Y    35
# Name: voluntary_softstory_retrofit, dtype: int64
# fire_only_permit
# Y    18820
# Name: fire_only_permit, dtype: int64
# tidf_compliance
# Y    1
# P    1
# Name: tidf_compliance, dtype: int64
# site_permit
# Y    5355
# Name: site_permit, dtype: int64

# %% [markdown]
# La presunción era cierta, salvo para la columna **tidf_compliance**. La documentación dice textual:
# *"TIDF compliant or not"* lo cual indicaría que debería ser un campo tipo *booleano*. Aquí haremos una suposición
# e intepretaremos a la letra P como "parcial", ya que se trata del cumplimiento o no de una normativa o estándar.

# %%
fill_cols = ['tidf_compliance', 'structural_notification', 'voluntary_softstory_retrofit', 'fire_only_permit', 'site_permit']
for col in fill_cols:
    data[col] = data[col].fillna(value='N')

# %% [markdown]
# ## Codificación de variables

# %% [markdown]
# ### Variable *location*

# %% [markdown]
# La columna *location* tiene la latitud y longitud de la edificación, que deberá ser separada en dos columnas distintas
# para su correcta utilización

# %%
data['latitude'], data['longitude'] = data['location'].str.split(',', 1).str
data.latitude = data.latitude.str.replace('(','')
data.longitude = data.longitude.str.replace(')','')
data.latitude = data.latitude.astype(float)
data.longitude = data.longitude.astype(float)
data = data.drop(['location'], 1)

# %%
data.longitude.sample(3)
# Out:
# Record ID
# 1491627400578   -122.433250
# 1468075364100   -122.430844
# 1430521183513   -122.413018
# Name: longitude, dtype: float64

# %% [markdown]
# ### Variables categóricas

# %% [markdown]
# Serán variables categóricas todas aquellas cuyo tipo es string, y no es un campo descriptivo (i.e. con texto libre).

# %%
from sklearn import preprocessing

categoric_vars = ['lot', 'permit_type', 'permit_type_definition', 'street_number_suffix', 'street_name', 'street_suffix', 'unit_suffix', \
                  'current_status', 'structural_notification', 'voluntary_softstory_retrofit', 'fire_only_permit', \
                  'existing_use', 'proposed_use', 'tidf_compliance', 'existing_construction_type_description', \
                  'proposed_construction_type_description', 'neighborhoods__analysis_boundaries' \
                 ]

# %% [markdown]
# En el caso de *neighborhoods__analysis_boundaries* parece que tenemos filas con más de una categoría.

# %%
data['neighborhoods__analysis_boundaries'].value_counts()
# Out:
# Financial District/South Beach    21808
# Mission                           14678
# Sunset/Parkside                   10204
# West of Twin Peaks                 8737
# Castro/Upper Market                8527
# Pacific Heights                    8505
# Marina                             8241
# Outer Richmond                     7850
# Noe Valley                         7842
# South of Market                    7565
# Bernal Heights                     6066
# Nob Hill                           6009
# Haight Ashbury                     5796
# Inner Sunset                       5774
# Bayview Hunters Point              5665
# Russian Hill                       5495
# Hayes Valley                       5488
# Tenderloin                         4781
# Inner Richmond                     4453
# Potrero Hill                       4289
# Presidio Heights                   4083
# North Beach                        4050
# Western Addition                   3866
# Chinatown                          3764
# Lone Mountain/USF                  3356
# Excelsior                          3071
# Oceanview/Merced/Ingleside         2654
# Glen Park                          2637
# Mission Bay                        2286
# Outer Mission                      2242
# Twin Peaks                         1701
# Portola                            1433
# Lakeshore                          1308
# Seacliff                            992
# Visitacion Valley                   900
# Japantown                           700
# Treasure Island                      81
# Golden Gate Park                     64
# Presidio                             51
# Lincoln Park                         49
# McLaren Park                         46
# Name: neighborhoods__analysis_boundaries, dtype: int64

# %% [markdown]
# En realidad, vemos que el caso de 'Castro/Upper Market' por tomar un ejemplo no es una doble categoría ya que no se observan ocurrencias de 'Castro' o 'Upper Market', por lo tanto podemos tomarlo (este y demás casos) como una sola catergoría.
#
# Hacemos lo mismo con las demás:

# %%
for col in categoric_vars:
    print(data[col].value_counts())
    print("\n")
# Out:
# 1       10111
# 7        5316
# 2        5182
# 3        5042
# 6        4833
# 8        4773
# 9        4590
# 5        4546
# 4        4381
# 11       4235
# 10       4159
# 12       4110
# 21       4089
# 14       4048
# 13       4032
# 16       3979
# 17       3913
# 20       3898
# 19       3863
# 18       3813
# 15       3734
# 22       3479
# 23       3390
# 26       3263
# 25       3125
# 28       2985
# 24       2936
# 32       2734
# 29       2659
# 27       2653
#         ...
# 847         1
# 050A        1
# 450         1
# 430         1
# 073C        1
# 17A         1
# 017H        1
# 504         1
# 582         1
# 518         1
# 601         1
# 018Y        1
# 387         1
# 043D        1
# 036D        1
# 300A        1
# 072A        1
# 072C        1
# 006N        1
# 371         1
# 013K        1
# 400         1
# 655         1
# 001Y        1
# 330         1
# 967         1
# 471         1
# 014Q        1
# 460         1
# 703         1
# Name: lot, Length: 1050, dtype: int64
#
#
# 8    178789
# 3     14651
# 4      2892
# 2       949
# 6       600
# 7       511
# 1       348
# 5        91
# Name: permit_type, dtype: int64
#
#
# otc alterations permit                 178789
# additions alterations or repairs        14651
# sign - erect                             2892
# new construction wood frame               949
# demolitions                               600
# wall or painted sign                      511
# new construction                          348
# grade or quarry or fill or excavate        91
# Name: permit_type_definition, dtype: int64
#
#
# A    1500
# B     290
# V     228
# C      56
# E      28
# F      24
# G      12
# D      11
# H      11
# K      11
# L      10
# R      10
# J       9
# I       7
# P       3
# N       2
# ½       1
# 0       1
# Name: street_number_suffix, dtype: int64
#
#
# Market                   5443
# California               4586
# Mission                  4208
# Montgomery               2403
# Geary                    1964
# 20th                     1859
# 03rd                     1817
# Folsom                   1775
# Pine                     1676
# Sacramento               1629
# Post                     1568
# Jackson                  1552
# Union                    1462
# 17th                     1457
# Pacific                  1449
# 18th                     1445
# Green                    1422
# Bush                     1402
# 19th                     1397
# 24th                     1361
# Sutter                   1342
# 16th                     1310
# Broadway                 1278
# Clay                     1274
# Vallejo                  1243
# 21st                     1233
# Washington               1214
# 02nd                     1207
# 15th                     1170
# 22nd                     1153
#                          ...
# Dorcas                      1
# Kimball                     1
# Augusta                     1
# Dicha                       1
# Cunningham                  1
# Reno                        1
# Bergen                      1
# Chain Of Lakes              1
# Cooper                      1
# Ridge                       1
# Yacht                       1
# Pizarro                     1
# Legion                      1
# Homewood                    1
# Willard St North            1
# Lessing                     1
# Vine                        1
# Richards                    1
# Mabrey                      1
# Letterman                   1
# Juan Bautista               1
# East Crystal Cove           1
# Erie                        1
# Fella                       1
# Tillman                     1
# Unknown                     1
# Martin Luther King Jr       1
# Roemer                      1
# Saint Joseph's              1
# Alder                       1
# Name: street_name, Length: 1704, dtype: int64
#
#
# St    138311
# Av     43203
# Bl      3552
# Wy      3540
# Dr      3267
# Tr      1465
# Ct       667
# Pl       538
# Rd       389
# Ln       354
# Hy       240
# Pz       209
# Pk       128
# Cr        97
# Al        83
# Wk         9
# Rw         5
# So         2
# Sw         2
# No         2
# Hl         1
# Name: street_suffix, dtype: int64
#
#
# A             346
# C             226
# B             191
# D             135
# E              92
# HOA            85
# F              78
# COMML          43
# W              43
# G              36
# RESID'L        33
# UPPER          23
# H              23
# REAR BLDG      23
# FRONT BLDG     23
# J              19
# C-1            18
# N              18
# 1/F            16
# T              16
# R              14
# P              13
# Garage         13
# BLDG 1         12
# FRONT          12
# C102           11
# REAR           11
# FRONT UNIT     10
# COMMERCIAL     10
# K              10
#              ...
# 2ND FLOOR       1
# BASEMENT        1
# PIER 1          1
# #R-2            1
# BLDG D          1
# HMETER          1
# D4              1
# I               1
# TOP             1
# BLDG E          1
# UTILITY         1
# UPPER LEVE      1
# BLDG. 3         1
# LEVEL ONE       1
# 3RD FLOOR       1
# C-4             1
# RESDL/REAR      1
# COMM'           1
# 1A-4            1
# RES'L           1
# COM-1           1
# U-PH3           1
# W122            1
# 3/F             1
# BLDG 201        1
# CU-2            1
# U               1
# BLDG 2          1
# PH C            1
# COML            1
# Name: unit_suffix, Length: 164, dtype: int64
#
#
# complete       97047
# issued         83532
# filed          12033
# withdrawn       1753
# cancelled       1535
# expired         1370
# approved         733
# reinstated       563
# suspend          193
# revoked           50
# plancheck         16
# appeal             2
# incomplete         2
# disapproved        2
# Name: current_status, dtype: int64
#
#
# N    191910
# Y      6921
# Name: structural_notification, dtype: int64
#
#
# N    198796
# Y        35
# Name: voluntary_softstory_retrofit, dtype: int64
#
#
# N    180011
# Y     18820
# Name: fire_only_permit, dtype: int64
#
#
# 1 family dwelling       46759
# apartments              40784
# office                  24608
# 2 family dwelling       20981
# retail sales             6908
# food/beverage hndlng     4885
# vacant lot               1813
# tourist hotel/motel      1663
# residential hotel        1020
# warehouse,no frnitur      868
# school                    674
# clinics-medic/dental      581
# manufacturing             510
# church                    467
# artist live/work          448
# lending institution       351
# auto repairs              335
# health studios & gym      239
# theater                   218
# filling/service stn       218
# barber/beauty salon       212
# prkng garage/public       206
# public assmbly other      195
# prkng garage/private      194
# workshop commercial       189
# recreation bldg           179
# museum                    146
# club                      124
# storage shed              113
# misc group residns.       113
#                         ...
# building materials         10
# nursing home non amb       10
# adult entertainment         9
# day care home lt 7          9
# chemical processing         9
# nursery(floral)             9
# fence/retaining wall        9
# amusement center            7
# jail                        6
# storage tanks               6
# sign                        5
# meat/produce marts          5
# paint store                 5
# nursing home lte 6          5
# workshop residential        5
# prson'l svc tutor           5
# accessory cottage           5
# swimming pool               5
# stadium                     4
# r-3(dwg) nursing            4
# sewage plant                4
# day care home 7 - 12        4
# ambulance service           3
# muni driver restroom        3
# temple                      2
# bath house                  2
# child care                  1
# orphanage                   1
# dairies/dairy equip.        1
# roofing materials           1
# Name: existing_use, Length: 93, dtype: int64
#
#
# 1 family dwelling       46339
# apartments              43017
# office                  23955
# 2 family dwelling       22055
# retail sales             5077
# food/beverage hndlng     5052
# tourist hotel/motel      1599
# residential hotel        1001
# school                    748
# clinics-medic/dental      678
# warehouse,no frnitur      672
# artist live/work          443
# manufacturing             436
# church                    434
# vacant lot                385
# health studios & gym      332
# barber/beauty salon       258
# lending institution       239
# auto repairs              238
# public assmbly other      227
# workshop commercial       219
# recreation bldg           207
# theater                   188
# prkng garage/public       174
# museum                    139
# club                      125
# misc group residns.       119
# antenna                   115
# massage parlor            104
# prkng garage/private      102
#                         ...
# mortuary                   12
# tower                      11
# day care home lt 7         11
# nursing home non amb       11
# day care home 7 - 12       11
# workshop residential       10
# chemical processing         9
# amusement center            8
# paint store                 6
# building materials          6
# sewage plant                6
# sign                        6
# swimming pool               6
# jail                        6
# storage tanks               5
# adult entertainment         5
# car wash                    5
# muni driver restroom        5
# accessory cottage           5
# bath house                  5
# nursing home lte 6          4
# r-3(dwg) nursing            4
# ambulance service           4
# stadium                     3
# temple                      2
# meat/produce marts          2
# roofing materials           1
# orphanage                   1
# dairies/dairy equip.        1
# not applicable              1
# Name: proposed_use, Length: 94, dtype: int64
#
#
# N    198829
# Y         1
# P         1
# Name: tidf_compliance, dtype: int64
#
#
# wood frame (5)    113314
# constr type 1      28065
# constr type 3       9660
# constr type 2       4066
# constr type 4        381
# Name: existing_construction_type_description, dtype: int64
#
#
# wood frame (5)    114345
# constr type 1      27833
# constr type 3       9357
# constr type 2       3776
# constr type 4        377
# Name: proposed_construction_type_description, dtype: int64
# Financial District/South Beach    21808
# Mission                           14678
# Sunset/Parkside                   10204
# West of Twin Peaks                 8737
# Castro/Upper Market                8527
# Pacific Heights                    8505
# Marina                             8241
# Outer Richmond                     7850
# Noe Valley                         7842
# South of Market                    7565
# Bernal Heights                     6066
# Nob Hill                           6009
# Haight Ashbury                     5796
# Inner Sunset                       5774
# Bayview Hunters Point              5665
# Russian Hill                       5495
# Hayes Valley                       5488
# Tenderloin                         4781
# Inner Richmond                     4453
# Potrero Hill                       4289
# Presidio Heights                   4083
# North Beach                        4050
# Western Addition                   3866
# Chinatown                          3764
# Lone Mountain/USF                  3356
# Excelsior                          3071
# Oceanview/Merced/Ingleside         2654
# Glen Park                          2637
# Mission Bay                        2286
# Outer Mission                      2242
# Twin Peaks                         1701
# Portola                            1433
# Lakeshore                          1308
# Seacliff                            992
# Visitacion Valley                   900
# Japantown                           700
# Treasure Island                      81
# Golden Gate Park                     64
# Presidio                             51
# Lincoln Park                         49
# McLaren Park                         46
# Name: neighborhoods__analysis_boundaries, dtype: int64

# %% [markdown]
# Procedemos a transformar a números estas categorías

# %% [markdown]
# #### Variables con  orden total

# %% [markdown]
# Convertimos en binario los valores de las 4 columnas a las que rellenamos los valores faltantes con 'N'.

# %%
from sklearn.preprocessing import LabelBinarizer

bin_vars = ['voluntary_softstory_retrofit', 'structural_notification', 'fire_only_permit', 'site_permit']
ord_vars = bin_vars + ['tidf_compliance']

for bin_col in bin_vars:
    lb = LabelBinarizer()
    lb_results = lb.fit_transform(data[bin_col])
    data[bin_col] = lb_results
    print(data[bin_col].value_counts())
# Out:
# 0    198796
# 1        35
# Name: voluntary_softstory_retrofit, dtype: int64
# 0    191910
# 1      6921
# Name: structural_notification, dtype: int64
# 0    180011
# 1     18820
# Name: fire_only_permit, dtype: int64
# 0    193476
# 1      5355
# Name: site_permit, dtype: int64

# %% [markdown]
# Para *tidf_compliance* usaremos otro convertidor ya que hay 3 valores posibles.
# Hay que procurar que el valor 'P' sea mapeado a 1, 'Y' a 2 y 'N' a 0.

# %%
P_index = data[data.tidf_compliance == 'P'].index
Y_index = data[data.tidf_compliance == 'Y'].index

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(['N','P','Y'])
data.tidf_compliance = le.transform(data.tidf_compliance)
data['tidf_compliance'].value_counts()
# Out:
# 0    198829
# 2         1
# 1         1
# Name: tidf_compliance, dtype: int64

# %% [markdown]
# Corroboramos que la 'P' haya sido mapeada al 1

# %%
print(data[data.tidf_compliance == 2].index == Y_index)
print(data[data.tidf_compliance == 1].index == P_index)
# Out:
# [ True]
# [ True]

# %% [markdown]
# #### Variables con valores no ordinales

# %% [markdown]
# Convertimos las variables que no deberían ser ordinales extrayendo cada valor posible en una nueva columna binaria.
# Para ello usamos el método 'get_dummies' de pandas en lugar de los encoders de sklearn

# %%
many_cat = [var for var in categoric_vars if var not in ord_vars]
dummies = pd.get_dummies(data, columns=many_cat, prefix=many_cat)
print(data.current_status.value_counts())
print(dummies.shape)
data = pd.concat([dummies, data])
print(data.shape)
# Out:
# complete       97047
# issued         83532
# filed          12033
# withdrawn       1753
# cancelled       1535
# expired         1370
# approved         733
# reinstated       563
# suspend          193
# revoked           50
# plancheck         16
# appeal             2
# incomplete         2
# disapproved        2
# Name: current_status, dtype: int64
# (198831, 3255)
# (397662, 3268)

# %% [markdown]
# ## Consistencia de las variables

# %% [markdown]
# Chequeamos que las fechas cargadas en cada fila sean consistentes entre sí. Por ejemplo, 'Permit Creation Date' no puede ser anterior a 'Filed Date' (lo dice la propia documentación).
# Los campos a revisar son entonces 'Filed Date', 'Permit Creation Date', 'Current Status Date' y 'Completed Date'.

# %%
(data['filed_date'] <= data['permit_creation_date']).value_counts()
# Out:
# True     396678
# False       984
# dtype: int64

# %% [markdown]
# Veamos las filas en las que las fechas son insconsistentes para corroborar tal hecho

# %%
data[data['filed_date'] > data['permit_creation_date']]
samples = data.sample(10)
print(samples['filed_date'])
print(samples['permit_creation_date'])
# Out:
# Record ID
# 1307439255952   2013-06-10
# 143405797435    2016-08-17
# 1476434136457   2017-08-28
# 1405685134580   2015-12-08
# 1481935487821   2017-10-03
# 147950492143    2017-09-15
# 1380456293356   2015-05-05
# 1465192464371   2017-06-01
# 1363699168319   2014-11-26
# 1326833165424   2013-12-11
# Name: filed_date, dtype: datetime64[ns]
# Record ID
# 1307439255952   2013-06-10
# 143405797435    2016-08-17
# 1476434136457   2017-08-28
# 1405685134580   2015-12-08
# 1481935487821   2017-10-03
# 147950492143    2017-09-15
# 1380456293356   2015-05-05
# 1465192464371   2017-06-01
# 1363699168319   2014-11-26
# 1326833165424   2013-12-11
# Name: permit_creation_date, dtype: datetime64[ns]

# %% [markdown]
# Vemos algunos casos en los que supuestamente hay inconsistencia, pero se trata en ambos casos de la misma fecha, lo cual según la documentación es legal. El falso positivo se debería a un problema con la comparación entre datetimes.
#
# Otra regla que hay que revisar si se cumple es que las filas con el campo 'Completed Date' tengan un valor únicamente si la columna originalmente nombrada como 'Current Status' es 'complete'

# %%
bad = data[(data['current_status_complete'] == 0) & ~(np.isnat(data['completed_date']))]
bad2 = data[(data['current_status_complete'] == 1) & (np.isnat(data['completed_date']))]
print(len(bad))
print(len(bad2))
# Out:
# 114
# 0

# %% [markdown]
# Hay 114 filas que son inconsistentes. Nos quedamos únicamente con las consistentes:

# %%
data = data[(data['current_status_complete'] == 0) & (np.isnat(data['completed_date']))]

# %% [markdown]
# ## Análisis y documentación de outliers

# %% [markdown]
# ### tidf_compliance

# %% [markdown]
# La columna 'tidf_compliance' si bien luego de este pre-procesamiento de datos muestra 3 valores, es conveniente
# dejar sentado que orignalmente esa columna posería una sola fila con un valor 'Y', otra con 'P' y el resto nulas.
# En este laboratorio se asumió que los valores faltantes se corresponden con un valor negativo. En otras columnas donde ocurría algo similar, la cantidad de valores 'Y' y valores faltantes eran más balanceadas que este caso extremo.

# %% [markdown]
# ## Comentarios finales

# %% [markdown]
# En el presente laboratorio se buscó realizar las limpiezas y conversiones de datos según el checklist sugerido en clase. Si bien el trabajo ha estado en nuestra consideración lejos de ser lo suficientemente exhaustivo como demandaría un caso real, lo que se ha buscado en el presente es mínimamente aplicar cada uno de los elementos del checklist en algunas columnas o valores.
#
# En el caso de las conversiones de variables categóricas, la cantidad de columnas generadas consideramos que es demasiado grande y requeriría un análisis mas meticuloso para determinar si todos los valores convertidos en columnas son realmente necesarios. Hay casos en los que un puñado de valores posibles tienen una frecuencia alta, y luego hay cientos de valores con 1 sola ocurrencia. Estos ultimos podrian, por ejemplo, agruparse en una categoría "otros" para generar una sola columna.
#
# No hemos podido almacenar en disco el dataframe resultante de todo este proceso de transformación, debido a su gran tamaño. Esto es por la conversión de las variables categóricas que se menciona en el párrafo anterior.
#
# Por último, para que esta proceso sea completo, sería necesario analizar más casos de outliers.
